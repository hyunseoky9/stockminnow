# %%
import pickle
filename = 'h_Hatchery3_2_4_20250825_201843.pkl'
with open(filename, 'rb') as f:
    data = pickle.load(f)

# %%
# Out:
# {'username': 'h',
#  'start_time': '2025-08-25T20:18:21.723074',
#  'initial_state': [4.795970503106569,
#   6.501706014762251,
#   5.967071593175115,
#   7.98508514338881,
#   7.74394878599323,
#   7.750028741082523,
#   19.92363779730288,
#   8.564766573774605],
#  'trajectory': [{'timestep': 1,
#    'state': [4.795970503106569,
#     6.501706014762251,
#     5.967071593175115,
#     7.98508514338881,
#     7.74394878599323,
#     7.750028741082523,
#     19.92363779730288,
#     8.564766573774605],
#    'action': [0.3, 0.3, 0.3, 0.1],
#    'reward': 10.207397891362353,
#    'next_state': [10.81822419045255,
#     9.490024989256312,
#     11.239701967869786,
#     6.561196730407523,
#     6.781818109568389,
#     4.975131761704191,
#     20.800286463206827,
#     8.612952549749558],
#    'done': False,
#    'info': {'Ne_score': [873.0333344047862],
#     'L': [0.8893321872333384, 0.6107070964228623, 0.6521292556825871],
#     'abqsf': [309800464.0947282],
# ...

# %%
from scipy.stats import hmean
x = [873.0333344047862,
  6086.158171617122,
  35726.4341776996,
  1550.108718600733,
  2717.9838838267133
  3596.0380366716554,
  896.6027941103556,
  4784.5657463022835,
  3071.0610162988633,
  13307.371255002354]
hmean_x = hmean(x
hmean_x
# Out:
# 2296.7691418280847
